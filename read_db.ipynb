# %%
import pandas as pd
from database import load_all_availabilities

# %%
rows = load_all_availabilities()

# %%
df = pd.DataFrame(rows)

# %%
df
# Out:
#                     0           1                 2
# 0  Renata Pocitarenco  2026-07-07              Free
# 1  Renata Pocitarenco  2026-07-14              Free
# 2  Renata Pocitarenco  2026-07-21              Free
# 3  Renata Pocitarenco  2026-07-28  Can make it work
